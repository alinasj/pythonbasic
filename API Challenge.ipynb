# %% [markdown]
# ## Assignment 1
# ###### write code to parse following "url" and print the following:
# no. of people on ISS: 10
# <br>name of people on the ISS:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Chris Cassidy<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Anatoly Ivanishin<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ivan Vagner<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Doug Hurley<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Bob Behnkenno

# %%
url = "http://api.open-notify.org/astros.json"

# %% [markdown]
# ## Assignment 2
# ###### write code to parse following "url" using a function:

# %% [markdown]
# #### Input

# %%
x = {'message': 'success', 'number': 5, 'people': [{'craft': 'ISS', 'name': 'Chris Cassidy'}, {'craft': 'ISS', 'name': 'Anatoly Ivanishin'}, {'craft': 'ISS', 'name': 'Ivan Vagner'}, {'craft': 'ISS', 'name': 'Doug Hurley'}, {'craft': 'ISS', 'name': 'Bob Behnken'}]}
y = {'message': 'success', 'number': 3, 'people': [{'craft': 'ISS', 'name': 'Lala Bulala'}, {'craft': 'ISS', 'name': 'Pucha Kutti'}, {'craft': 'ISS', 'name': 'Frosty Murali'}]}

# %% [markdown]
# #### Output for x
# no. of people on ISS: 5<br>name of people on the ISS:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Chris Cassidy<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Anatoly Ivanishin<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Ivan Vagner<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Doug Hurley<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Bob Behnkenno
# #### Output for y
# no. of people on ISS: 3<br>name of people on the ISS:<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Lala Bulala<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Pucha Kutti<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Frosty Murali

# %%
import requests

# %%
xkcd_response = requests.get("https://xkcd.com/info.0.json")

# %%
xkcd_response.json()
# Out:
# {'month': '6',
#  'num': 2324,
#  'link': '',
#  'year': '2020',
#  'news': '',
#  'safe_title': 'Old Days 2',
#  'transcript': '',
#  'alt': "The git vehicle fleet eventually pivoted to selling ice cream, but some holdovers remain. If you flag down an ice cream truck and hand the driver a floppy disk, a few hours later you'll get an invite to a git repo.",
#  'img': 'https://imgs.xkcd.com/comics/old_days_2.png',
#  'title': 'Old Days 2',
#  'day': '24'}

# %%
import urllib.request
from PIL import Image
url = 'https://imgs.xkcd.com/comics/old_days_2.png'
image = Image.open(urllib.request.urlopen(url))

# %%
type(image)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x572 at 0x7FE2D230DE90>

# %%
True
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
"True"
# Out:
# 'True'

# %%
type("True")
# Out:
# str

# %%
url = "https://www.metaweather.com/api/location/search/?query=philadelphia"

# %%
weather = requests.get(url)

# %%
weather.json()[0]["woeid"]
# Out:
# 2471217

# %%
w_id = 2471217
x = "https://www.metaweather.com/api/location/{}/".format(w_id)
print(x)
# Out:
# https://www.metaweather.com/api/location/2471217/

# %%
urs2 = "https://www.metaweather.com/api/location/2471217/"
response = requests.get(urs2)

# %%
response.json()['consolidated_weather'][0]
# Out:
# {'id': 5006731790778368,
#  'weather_state_name': 'Light Cloud',
#  'weather_state_abbr': 'lc',
#  'wind_direction_compass': 'WNW',
#  'created': '2020-06-26T15:18:37.546870Z',
#  'applicable_date': '2020-06-26',
#  'min_temp': 21.96,
#  'max_temp': 30.37,
#  'the_temp': 30.200000000000003,
#  'wind_speed': 5.8772628033590495,
#  'wind_direction': 286.83217208173033,
#  'air_pressure': 1015.0,
#  'humidity': 40,
#  'visibility': 15.198117990932952,
#  'predictability': 70}

# %%
#writing a function to take in "location name" and display the corresponding weather in that location

# %%
def weather_parser(location):
    url = "https://www.metaweather.com/api/location/search/?query={}".format(location)
    response = requests.get(url)
    weather_id = response.json()[0]["woeid"]
    weather_url = "https://www.metaweather.com/api/location/{}/".format(weather_id)
    print(requests.get(weather_url).json()['consolidated_weather'][0])

# %%
weather_parser("miami")
# Out:
# {'id': 5358091925192704, 'weather_state_name': 'Light Cloud', 'weather_state_abbr': 'lc', 'wind_direction_compass': 'E', 'created': '2020-06-26T16:03:37.488091Z', 'applicable_date': '2020-06-26', 'min_temp': 28.445, 'max_temp': 31.42, 'the_temp': 30.85, 'wind_speed': 8.809460601264616, 'wind_direction': 87.0, 'air_pressure': 1022.0, 'humidity': 69, 'visibility': 14.106679491768075, 'predictability': 70}

# %%
python weather.py "philadelphia"
